# %% [markdown]
# ## Cleaning Dataset

# %%
import pandas as pd
import requests
import time
import googlemaps
import folium
df = pd.read_csv("C:/Users/khapr/OneDrive/Documents/MS BIOSTAT/HSHV/FullHSHVData2.csv")

# %% [markdown]
# #### Rewrite the addresses so they are more interpretable by GeocodeAPI

# %%
df['Jurisdiction In'] = df['Jurisdiction In'].replace(r'^WC-', '', regex=True)  # Remove WC-
df['Jurisdiction In'] = df['Jurisdiction In'].replace(r'\s+(Twp|City)$', '', regex=True)
df['Location Found'] = df['Location Found'].replace('/', ' and ', regex=True)

# %% [markdown]
# #### Get latitude and longitutde for each address

# %%
df[['lon', 'lat']] = df['pnt'].str.split(', ', expand=True)
df['lat'] = pd.to_numeric(df['lat'], errors='coerce')  
df['lon'] = pd.to_numeric(df['lon'], errors='coerce')

# %%
API_KEY = 'AIzaSyCQhSlO7I12W_LENQsmU_JMkT7hFa4zmRw'
gmaps = googlemaps.Client(key=API_KEY)
condition_1 = ~df['address_google'].str.contains('MI|Michigan', na=False)
condition_2 = df['address_google'] == 'Michigan, USA'
incorrect_coords_df = df[condition_1 | condition_2].copy()

latitudes = []
longitudes = []
addresses = []

for index, row in incorrect_coords_df.iterrows():
    address = f"{row['Location Found']}, {row['Jurisdiction In']}, MI, USA"
    try:
        geocode_result = gmaps.geocode(address)
        if geocode_result:
            location = geocode_result[0]['geometry']['location']
            latitudes.append(location['lat'])
            longitudes.append(location['lng'])
            addresses.append(geocode_result[0]['formatted_address'])
        else:
            latitudes.append(None)
            longitudes.append(None)
            addresses.append(None)
    except Exception as e:
        print(f"Error geocoding {address}: {e}")
        latitudes.append(None)
        longitudes.append(None)
        addresses.append(None)

# %%
incorrect_coords_df.loc[:, 'Latitude'] = latitudes
incorrect_coords_df.loc[:, 'Longitude'] = longitudes
incorrect_coords_df.loc[:, 'google_address_corrected'] = addresses
print(incorrect_coords_df)
# Out:
#         ...1     Animal # Species        Primary Breed Gender Altered  \
# 68        69  A0043487853     Cat   Domestic Shorthair      M     Yes
# 81        82  A0018665727     Dog  Retriever, Labrador      F     Yes
# 120      121  A0041719634     Dog       Siberian Husky      F     Yes
# 209      210  A0042677934     Cat   Domestic Shorthair      F     Yes
# 228      229  A0045913101     Dog    Terrier, Pit Bull      M     Yes
# ...      ...          ...     ...                  ...    ...     ...
# 11285  11286  A0054093167  Rodent           Guinea Pig      F      No
# 11306  11307  A0054109808     Cat   Domestic Shorthair      F     Yes
# 11314  11315  A0054115024     Cat   Domestic Shorthair      F     Yes
# 11315  11316  A0054115026     Cat    Domestic Longhair      F     Yes
# 11316  11317  A0054115027     Cat   Domestic Shorthair      F     Yes
#
#             Intake Date    Intake Subtype                      Location Found  \
# 68     12/24/2019 10:53  Stray without ID             Miller Ave & Newport Rd
# 81      12/9/2019 17:39     Stray with ID                     Adoptions lobby
# 120     5/19/2019 11:52     Stray with ID         Dawn Avenue & Stamford Road
# 209      9/7/2019 16:27     Stray with ID                  Clinton and Wilbur
# 228    10/17/2020 13:23  Stray without ID             S Harris Rd & Ecorse Rd
# ...                 ...               ...                                 ...
# 11285    9/5/2023 14:04  Stray without ID              Vaughn St & Packard St
# 11306    9/7/2023 14:21  Stray without ID         Austin btwn Eisman and Kies
# 11314    9/8/2023 11:19      Kitten/Puppy  M-52 btwn Pleasant Lake and Pekins
# 11315    9/8/2023 11:19      Kitten/Puppy  M-52 btwn Pleasant Lake and Pekins
# 11316    9/8/2023 11:19      Kitten/Puppy  M-52 btwn Pleasant Lake and Pekins
#
#       Jurisdiction In  ... ...22    ...23  \
# 68          Ann Arbor  ...    MI  48168.0
# 81               HSHV  ...   NaN      NaN
# 120          Superior  ...    MI  48198.0
# 209       Bridgewater  ...    MI  48130.0
# 228         Ypsilanti  ...    MI  48198.0
# ...               ...  ...   ...      ...
# 11285       Ann Arbor  ...   NaN      NaN
# 11306     Bridgewater  ...   NaN      NaN
# 11314          Sharon  ...   NaN      NaN
# 11315          Sharon  ...   NaN      NaN
# 11316          Sharon  ...   NaN      NaN
#
#                                             LocationPlus  \
# 68     Miller Ave & Newport Rd WC-Ann Arbor City , Mi...
# 81                    Adoptions lobby WC-HSHV , Michigan
# 120    Dawn Avenue & Stamford Road WC-Superior Twp , ...
# 209     Clinton and Wilbur WC-Bridgewater Twp , Michigan
# 228    S Harris Rd & Ecorse Rd WC-Ypsilanti Twp , Mic...
# ...                                                  ...
# 11285  Vaughn St & Packard St WC-Ann Arbor City , Mic...
# 11306  Austin btwn Eisman and Kies WC-Bridgewater Twp...
# 11314  M-52 btwn Pleasant Lake and Pekins WC-Sharon T...
# 11315  M-52 btwn Pleasant Lake and Pekins WC-Sharon T...
# 11316  M-52 btwn Pleasant Lake and Pekins WC-Sharon T...
#
#                          address_google                      pnt        lon  \
# 68      Miller Ave, Fort Worth, TX, USA  -97.2629362, 32.7050086 -97.262936
# 81                        Michigan, USA  -85.6023643, 44.3148443 -85.602364
# 120                                 NaN                   NA, NA        NaN
# 209                       Michigan, USA  -85.6023643, 44.3148443 -85.602364
# 228    S Harris Rd, Arkansas 71964, USA  -93.2429071, 34.4201844 -93.242907
# ...                                 ...                      ...        ...
# 11285                               NaN                   NA, NA        NaN
# 11306                     Michigan, USA  -85.6023643, 44.3148443 -85.602364
# 11314                     Michigan, USA  -85.6023643, 44.3148443 -85.602364
# 11315                     Michigan, USA  -85.6023643, 44.3148443 -85.602364
# 11316                     Michigan, USA  -85.6023643, 44.3148443 -85.602364
#
#              lat   Latitude  Longitude  \
# 68     32.705009  42.288870 -83.765586
# 81     44.314844  42.306347 -83.654994
# 120          NaN  42.263461 -83.580555
# 209    44.314844  42.119513 -83.967337
# 228    34.420184  42.234962 -83.582658
# ...          ...        ...        ...
# 11285        NaN  42.268556 -83.738085
# 11306  44.314844  42.139379 -83.970092
# 11314  44.314844  42.221662 -84.080161
# 11315  44.314844  42.221662 -84.080161
# 11316  44.314844  42.221662 -84.080161
#
#                                 google_address_corrected
# 68     Miller Ave & Newport Rd, Ann Arbor, MI 48103, USA
# 81         3100 Cherry Hill Rd, Ann Arbor, MI 48105, USA
# 120    Dawn Ave & Stamford Rd, Superior Charter Twp, ...
# 209    Clinton Rd & Wilbur Rd, Bridgewater Township, ...
# 228    S Harris Rd & Ecorse Rd, Ypsilanti Charter Twp...
# ...                                                  ...
# 11285   Vaughn St & Packard St, Ann Arbor, MI 48104, USA
# 11306       Kies Rd, Bridgewater Township, MI 48158, USA
# 11314                           Sharon Township, MI, USA
# 11315                           Sharon Township, MI, USA
# 11316                           Sharon Township, MI, USA
#
# [636 rows x 31 columns]

# %% [markdown]
# #### Remove observations found at HSHV

# %%
incorrect_coords_df.loc[incorrect_coords_df['LocationPlus'].str.contains('HSHV', na=False), 'address_google'] = '3100 Cherry Hill Rd, Ann Arbor, MI 48105'
incorrect_coords_df.loc[incorrect_coords_df['LocationPlus'].str.contains('HSHV', na=False), 'google_address_corrected'] = '3100 Cherry Hill Rd, Ann Arbor, MI 48105'
incorrect_coords_df.loc[incorrect_coords_df['LocationPlus'].str.contains('HSHV', na=False), 'Latitude'] = 42.306139
incorrect_coords_df.loc[incorrect_coords_df['LocationPlus'].str.contains('HSHV', na=False), 'lat'] = 42.306139
incorrect_coords_df.loc[incorrect_coords_df['LocationPlus'].str.contains('HSHV', na=False), 'Longitude'] = -83.654887
incorrect_coords_df.loc[incorrect_coords_df['LocationPlus'].str.contains('HSHV', na=False), 'lon'] = -83.654887

# %%
df.loc[incorrect_coords_df.index, 'lat'] = incorrect_coords_df['Latitude']
df.loc[incorrect_coords_df.index, 'lon'] = incorrect_coords_df['Longitude']
df.loc[incorrect_coords_df.index, 'address_google'] = incorrect_coords_df['google_address_corrected']

# %% [markdown]
# #### Find the observations that are just Michigan, USA and manually change them

# %%
incorrect_coords_df[incorrect_coords_df['google_address_corrected'] == 'Michigan, USA']
# Out:
#         ...1     Animal # Species       Primary Breed Gender Altered  \
# 2867    2868  A0041587203     Cat  Domestic Shorthair      F     Yes
# 5215    5216  A0049120683     Cat  Domestic Shorthair      M     Yes
# 5219    5220  A0051573388     Cat  Domestic Shorthair      F     Yes
# 5227    5228  A0049121987     Cat  Domestic Shorthair      F     Yes
# 7014    7015  A0050897660     Cat  Domestic Shorthair      F     Yes
# 7015    7016  A0050897662     Cat  Domestic Shorthair      M      No
# 7291    7292  A0048387156     Cat  Domestic Shorthair      F     Yes
# 11202  11203  A0056964944     Cat  Domestic Shorthair      M     Yes
# 11203  11204  A0056964946     Cat  Domestic Shorthair      F     Yes
# 11204  11205  A0056964949     Cat  Domestic Shorthair      F     Yes
# 11205  11206  A0056964951     Cat  Domestic Shorthair      F     Yes
# 11206  11207  A0056964940     Cat  Domestic Shorthair      F     Yes
#
#             Intake Date    Intake Subtype                Location Found  \
# 2867     5/3/2019 14:26  Stray without ID        Holmes  and  Ford Blvd
# 5215   11/21/2021 15:57     Orphan Animal              Norman and Owens
# 5219   11/21/2022 16:01  Stray without ID           Central and Main St
# 5227    11/22/2021 9:23     Orphan Animal  West college and Park street
# 7014    8/15/2022 14:27     Orphan Animal             Mowery and Thayer
# 7015    8/15/2022 14:27     Orphan Animal             Mowery and Thayer
# 7291      8/6/2021 9:10  Stray without ID             I-475 near Toledo
# 11202   9/26/2024 18:36      Kitten/Puppy               Hull and Barnes
# 11203   9/26/2024 18:36      Kitten/Puppy               Hull and Barnes
# 11204   9/26/2024 18:36      Kitten/Puppy               Hull and Barnes
# 11205   9/26/2024 18:36      Kitten/Puppy               Hull and Barnes
# 11206   9/26/2024 18:36  Stray without ID               Hull and Barnes
#
#            Jurisdiction In  ... ...22 ...23  \
# 2867                  York  ...   NaN   NaN
# 5215   Other Out of County  ...   NaN   NaN
# 5219                Dexter  ...   NaN   NaN
# 5227   Other Out of County  ...   NaN   NaN
# 7014          Out of State  ...   NaN   NaN
# 7015          Out of State  ...   NaN   NaN
# 7291          Out of State  ...   NaN   NaN
# 11202  Other Out of County  ...   NaN   NaN
# 11203  Other Out of County  ...   NaN   NaN
# 11204  Other Out of County  ...   NaN   NaN
# 11205  Other Out of County  ...   NaN   NaN
# 11206  Other Out of County  ...   NaN   NaN
#
#                                             LocationPlus  \
# 2867           Holmes / Ford Blvd WC-York Twp , Michigan
# 5215     Norman and Owens Other Out of County , Michigan
# 5219        Central and Main St WC-Dexter Twp , Michigan
# 5227   West college and Park street Other Out of Coun...
# 7014           Mowery and Thayer Out of State , Michigan
# 7015           Mowery and Thayer Out of State , Michigan
# 7291           I-475 near Toledo Out of State , Michigan
# 11202     Hull and Barnes Other Out of County , Michigan
# 11203     Hull and Barnes Other Out of County , Michigan
# 11204     Hull and Barnes Other Out of County , Michigan
# 11205     Hull and Barnes Other Out of County , Michigan
# 11206     Hull and Barnes Other Out of County , Michigan
#
#                address_google                      pnt        lon        lat  \
# 2867            Michigan, USA  -85.6023643, 44.3148443 -85.602364  44.314844
# 5215            Michigan, USA  -85.6023643, 44.3148443 -85.602364  44.314844
# 5219            Michigan, USA  -85.6023643, 44.3148443 -85.602364  44.314844
# 5227            Michigan, USA  -85.6023643, 44.3148443 -85.602364  44.314844
# 7014            Michigan, USA  -85.6023643, 44.3148443 -85.602364  44.314844
# 7015            Michigan, USA  -85.6023643, 44.3148443 -85.602364  44.314844
# 7291   I-475, Toledo, OH, USA  -83.6933438, 41.6297286 -83.693344  41.629729
# 11202           Michigan, USA  -85.6023643, 44.3148443 -85.602364  44.314844
# 11203           Michigan, USA  -85.6023643, 44.3148443 -85.602364  44.314844
# 11204           Michigan, USA  -85.6023643, 44.3148443 -85.602364  44.314844
# 11205           Michigan, USA  -85.6023643, 44.3148443 -85.602364  44.314844
# 11206           Michigan, USA  -85.6023643, 44.3148443 -85.602364  44.314844
#
#         Latitude  Longitude  google_address_corrected
# 2867   44.314844 -85.602364             Michigan, USA
# 5215   44.314844 -85.602364             Michigan, USA
# 5219   44.314844 -85.602364             Michigan, USA
# 5227   44.314844 -85.602364             Michigan, USA
# 7014   44.314844 -85.602364             Michigan, USA
# 7015   44.314844 -85.602364             Michigan, USA
# 7291   44.314844 -85.602364             Michigan, USA
# 11202  44.314844 -85.602364             Michigan, USA
# 11203  44.314844 -85.602364             Michigan, USA
# 11204  44.314844 -85.602364             Michigan, USA
# 11205  44.314844 -85.602364             Michigan, USA
# 11206  44.314844 -85.602364             Michigan, USA
#
# [12 rows x 31 columns]

# %%
df['pnt'] = df['lon'].astype(str) + ', ' + df['lat'].astype(str)

# %%
df[df['address_google'] == 'Michigan, USA']
# Out:
#         ...1     Animal # Species       Primary Breed Gender Altered  \
# 2867    2868  A0041587203     Cat  Domestic Shorthair      F     Yes
# 5215    5216  A0049120683     Cat  Domestic Shorthair      M     Yes
# 5219    5220  A0051573388     Cat  Domestic Shorthair      F     Yes
# 5227    5228  A0049121987     Cat  Domestic Shorthair      F     Yes
# 7014    7015  A0050897660     Cat  Domestic Shorthair      F     Yes
# 7015    7016  A0050897662     Cat  Domestic Shorthair      M      No
# 7291    7292  A0048387156     Cat  Domestic Shorthair      F     Yes
# 11202  11203  A0056964944     Cat  Domestic Shorthair      M     Yes
# 11203  11204  A0056964946     Cat  Domestic Shorthair      F     Yes
# 11204  11205  A0056964949     Cat  Domestic Shorthair      F     Yes
# 11205  11206  A0056964951     Cat  Domestic Shorthair      F     Yes
# 11206  11207  A0056964940     Cat  Domestic Shorthair      F     Yes
#
#             Intake Date    Intake Subtype                Location Found  \
# 2867     5/3/2019 14:26  Stray without ID        Holmes  and  Ford Blvd
# 5215   11/21/2021 15:57     Orphan Animal              Norman and Owens
# 5219   11/21/2022 16:01  Stray without ID           Central and Main St
# 5227    11/22/2021 9:23     Orphan Animal  West college and Park street
# 7014    8/15/2022 14:27     Orphan Animal             Mowery and Thayer
# 7015    8/15/2022 14:27     Orphan Animal             Mowery and Thayer
# 7291      8/6/2021 9:10  Stray without ID             I-475 near Toledo
# 11202   9/26/2024 18:36      Kitten/Puppy               Hull and Barnes
# 11203   9/26/2024 18:36      Kitten/Puppy               Hull and Barnes
# 11204   9/26/2024 18:36      Kitten/Puppy               Hull and Barnes
# 11205   9/26/2024 18:36      Kitten/Puppy               Hull and Barnes
# 11206   9/26/2024 18:36  Stray without ID               Hull and Barnes
#
#            Jurisdiction In  ... Returned to Address ...20 ...21 ...22  ...23  \
# 2867                  York  ...                 NaN   NaN   NaN   NaN    NaN
# 5215   Other Out of County  ...                 NaN   NaN   NaN   NaN    NaN
# 5219                Dexter  ...                 NaN   NaN   NaN   NaN    NaN
# 5227   Other Out of County  ...                 NaN   NaN   NaN   NaN    NaN
# 7014          Out of State  ...                 NaN   NaN   NaN   NaN    NaN
# 7015          Out of State  ...                 NaN   NaN   NaN   NaN    NaN
# 7291          Out of State  ...                 NaN   NaN   NaN   NaN    NaN
# 11202  Other Out of County  ...                 NaN   NaN   NaN   NaN    NaN
# 11203  Other Out of County  ...                 NaN   NaN   NaN   NaN    NaN
# 11204  Other Out of County  ...                 NaN   NaN   NaN   NaN    NaN
# 11205  Other Out of County  ...                 NaN   NaN   NaN   NaN    NaN
# 11206  Other Out of County  ...                 NaN   NaN   NaN   NaN    NaN
#
#                                             LocationPlus address_google  \
# 2867           Holmes / Ford Blvd WC-York Twp , Michigan  Michigan, USA
# 5215     Norman and Owens Other Out of County , Michigan  Michigan, USA
# 5219        Central and Main St WC-Dexter Twp , Michigan  Michigan, USA
# 5227   West college and Park street Other Out of Coun...  Michigan, USA
# 7014           Mowery and Thayer Out of State , Michigan  Michigan, USA
# 7015           Mowery and Thayer Out of State , Michigan  Michigan, USA
# 7291           I-475 near Toledo Out of State , Michigan  Michigan, USA
# 11202     Hull and Barnes Other Out of County , Michigan  Michigan, USA
# 11203     Hull and Barnes Other Out of County , Michigan  Michigan, USA
# 11204     Hull and Barnes Other Out of County , Michigan  Michigan, USA
# 11205     Hull and Barnes Other Out of County , Michigan  Michigan, USA
# 11206     Hull and Barnes Other Out of County , Michigan  Michigan, USA
#
#                                   pnt        lon        lat
# 2867   -85.60236429999999, 44.3148443 -85.602364  44.314844
# 5215   -85.60236429999999, 44.3148443 -85.602364  44.314844
# 5219   -85.60236429999999, 44.3148443 -85.602364  44.314844
# 5227   -85.60236429999999, 44.3148443 -85.602364  44.314844
# 7014   -85.60236429999999, 44.3148443 -85.602364  44.314844
# 7015   -85.60236429999999, 44.3148443 -85.602364  44.314844
# 7291   -85.60236429999999, 44.3148443 -85.602364  44.314844
# 11202  -85.60236429999999, 44.3148443 -85.602364  44.314844
# 11203  -85.60236429999999, 44.3148443 -85.602364  44.314844
# 11204  -85.60236429999999, 44.3148443 -85.602364  44.314844
# 11205  -85.60236429999999, 44.3148443 -85.602364  44.314844
# 11206  -85.60236429999999, 44.3148443 -85.602364  44.314844
#
# [12 rows x 28 columns]

# %%
df.to_csv('C:/Users/khapr/OneDrive/Documents/MS BIOSTAT/HSHV/finalcorrected_hshvNov18.csv', index=False)

# %% [markdown]
# #### 1. Based on Wendy's Feedback Remove animals found at HSHV
# #### 2. Remove Out of State Observations

# %%
final_df = pd.read_csv("C:/Users/khapr/OneDrive/Documents/MS BIOSTAT/HSHV/finalhandcorrected_hshvNov18.csv")

# %%
final_df = final_df[~final_df['Location Found'].str.contains('HSHV', na=False)]
final_df = final_df[final_df['address_google'].str.contains('MI', na=False)]

# %%
final_df.to_csv('C:/Users/khapr/OneDrive/Documents/MS BIOSTAT/HSHV/final_excludinghshvNov19.csv', index=False)

# %% [markdown]
# ## Folium

# %%
folium_df = pd.read_csv("C:/Users/khapr/OneDrive/Documents/MS BIOSTAT/HSHV/final_excludinghshvNov19.csv")

# %%
print(folium_df[['lat', 'lon']].isnull().sum())
# Out:
# lat    0
# lon    0
# dtype: int64

# %%
folium_df['lat'] = pd.to_numeric(folium_df['lat'], errors='coerce')
folium_df['lon'] = pd.to_numeric(folium_df['lon'], errors='coerce')
folium_df['pnt_split'] = folium_df['pnt'].str.split(',').str[1].str.strip() 
folium_df.loc[folium_df['lat'].isnull(), 'lat'] = pd.to_numeric(folium_df['pnt_split'], errors='coerce')
folium_df.drop(columns=['pnt_split'], inplace=True)

# %% [markdown]
# #### Heatmap of where animals have been found

# %%
from folium.plugins import HeatMap
map_center = [folium_df['lat'].mean(), folium_df['lon'].mean()]
m = folium.Map(location=map_center, zoom_start=10)
heat_data = folium_df[['lat', 'lon']].values.tolist()
HeatMap(heat_data, radius=15).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_89190c3b5e15750949c26decfbf66663 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_89190c3b5e15750949c26decfbf66663&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_89190c3b5e15750949c26decfbf66663 = L.map(
#                 &quot;map_89190c3b5e15750949c26decfbf66663&quot;,
#                 {
#                     center: [42.26574495539142, -83.68048131995671],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ca09ade0be60d170b5f16c20083d94e8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ca09ade0be60d170b5f16c20083d94e8.addTo(map_89190c3b5e15750949c26decfbf66663);
#
#
#             var heat_map_d5dc084eaa428026e8d1e24c41aa76fb = L.heatLayer(
#                 [[42.210799, -83.5819195], [42.230374, -83.6995447], [42.242459, -83.7984686], [42.2335459, -83.6201156], [42.243699, -83.6289739], [42.2457404, -83.5463831], [42.2101369, -83.6194916], [42.289214, -83.76631], [42.2412324, -83.5802177], [42.2412324, -83.5802177], [42.2101369, -83.6194916], [42.253766, -83.7667756], [42.2101369, -83.6194916], [42.213804, -83.544421], [42.3046849, -83.6044771], [42.235002, -83.645903], [42.2979795, -83.7213902], [42.2412324, -83.5802177], [42.2709114, -83.7406201], [42.2036842, -83.5431817], [42.3035028, -83.653651], [42.2411499, -83.6129939], [42.2560381, -83.6295775], [42.1568846, -83.6972154], [42.2303704, -83.6996729], [42.2314734, -83.6027718], [42.3721466, -83.6629493], [42.3046849, -83.6044771], [42.1992248, -83.5651156], [42.1666801, -83.7813167], [42.2306712, -83.638874], [42.2594101, -83.6612184], [42.0829839, -83.6766434], [42.210799, -83.5819195], [42.3093043, -83.6774765], [42.1575648, -83.5814202], [42.2449466, -83.6609532], [42.1679374, -83.4419256], [42.3158206, -83.780132], [42.230374, -83.6995447], [42.3586272, -83.5086986], [42.2883847, -83.8385504], [42.3172392, -83.6483248], [42.2450694, -83.7001271], [42.2450694, -83.7001271], [42.2499921, -83.5831599], [42.3134165, -84.0203556], [42.2450694, -83.7001271], [42.2101369, -83.6194916], [42.2450694, -83.7001271], [42.2455332, -83.6804906], [42.2753142, -83.7712151], [42.2534729, -83.6029146], [42.3669869, -83.6072652], [42.3586272, -83.5086986], [42.2412324, -83.5802177], [42.2380381, -83.6245898], [42.21361, -83.557431], [42.2101369, -83.6194916], [42.1560762, -83.6530316], [42.2302096, -83.6606109], [42.2196857, -83.6603068], [42.2944721, -83.7802448], [42.1716979, -83.6792563], [42.2962151, -83.7309258], [42.288742, -83.6529707], [42.2027786, -83.581733], [42.2888697, -83.7655861], [42.202561, -83.609847], [42.3653661, -83.8260884], [42.2561271, -83.5441086], [42.2412324, -83.5802177], [42.1357921, -83.6778336], [42.1357921, -83.6778336], [42.2314734, -83.6027718], [42.2031269, -83.9340528], [42.241168, -83.582753], [42.258063, -83.562182], [42.1557297, -83.7377357], [42.3817593, -83.8234029], [42.306139, -83.654887], [42.3046849, -83.6044771], [42.1703662, -83.7699827], [42.2607809, -83.7298785], [42.3255802, -83.8394495], [42.288079, -83.838546], [42.259215, -83.607771], [42.2562631, -83.7111541], [42.2440692, -83.719857], [42.3602997, -83.7711439], [42.1872525, -83.6205697], [42.2506803, -83.624089], [42.3817593, -83.8234029], [41.9857288, -83.3688523], [42.2458513, -83.6263711], [42.1810072, -83.5739128], [42.2580513, -83.6625715], [42.230374, -83.6995447], [42.2868754, -83.8260884], [42.2101369, -83.6194916], [42.230374, -83.6995447], [42.2755979, -83.6030416], [42.2101369, -83.6194916], [42.2833599, -83.7012017], [42.2947202, -83.7807865], [42.30416, -83.707201], [42.2833599, -83.7012017], [42.247677, -83.719853], [42.2459938, -83.6085497], [42.062968, -83.650484], [42.3170217, -83.7067277], [42.306117, -83.709707], [42.2868754, -83.8260884], [42.2868754, -83.8260884], [42.4325296, -83.1028274], [42.3025991, -83.70431], [42.2501431, -83.6610765], [42.2560381, -83.6295775], [42.3255802, -83.8394495], [42.2634589, -83.5805566], [42.181727, -83.542378], [42.2779521, -83.7585343], [42.1666801, -83.7813167], [42.2760992, -83.5834128], [42.2560381, -83.6295775], [42.2808256, -83.7430378], [42.3161944, -83.7341529], [42.2335459, -83.6201156], [42.2297949, -83.7195774], [42.1417412, -83.7142811], [42.2101369, -83.6194916], [42.3046849, -83.6044771], [42.2101369, -83.6194916], [42.2808256, -83.7430378], [42.3290415, -83.6169352], [42.1460527, -84.0468632], [42.2939293, -83.8779342], [42.202931, -83.582843], [42.2814211, -83.7485636], [42.2808256, -83.7430378], [42.300452, -83.7358149], [42.2809974, -83.7818094], [42.3064258, -83.743507], [42.3064258, -83.743507], [42.2461577, -83.5978184], [42.202561, -83.609847], [42.25

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# #### 7803 rows with full addresses, 2825 without full addresses

# %%
sum(folium_df['address_google'] == 'Ypsilanti Charter Twp, MI, USA')/sum(final_df['address_google'].str.contains('Ypsilanti Charter Twp', na=False))
# Out:
# 0.31175556706369756

# %%
sum(folium_df['address_google'] == 'Superior Charter Twp, MI, USA')/sum(final_df['address_google'].str.contains('Superior Charter Twp', na=False))
# Out:
# 0.15861214374225527

# %%
folium_df['address_no_zipcode'] = ~folium_df['address_google'].str.contains(r'\b\d{5}\b')
hshv_no_zipcode = folium_df[folium_df['address_no_zipcode'] == True]
hshv_no_zipcode
# Out:
#         ...1     Animal # Species          Primary Breed Gender Altered  \
# 1          2  A0040554409     Dog    Retriever, Labrador      F     Yes
# 5          6  A0040588619     Dog  Chihuahua, Short Coat      M      No
# 6          7  A0040598374     Cat     Domestic Shorthair      M     Yes
# 10        11  A0040613747     Cat     Domestic Shorthair      M     Yes
# 12        13  A0005951543     Cat     Domestic Shorthair      F     Yes
# ...      ...          ...     ...                    ...    ...     ...
# 10613  11325  A0054114230     Cat     Domestic Shorthair      F     Yes
# 10614  11326  A0056843133     Dog      Terrier, Pit Bull      F     Yes
# 10618  11330  A0054122829     Dog      Poodle, Miniature      F     Yes
# 10619  11331  A0054121764     Cat     Domestic Shorthair      F      No
# 10627  11340  A0049406005     Cat     Domestic Shorthair      F     Yes
#
#            Intake Date    Intake Subtype  \
# 1      1/12/2019 15:06     Stray with ID
# 5      1/17/2019 14:16  Stray without ID
# 6      1/18/2019 15:44  Stray without ID
# 10      1/22/2019 8:49  Stray without ID
# 12     1/24/2019 12:09     Stray with ID
# ...                ...               ...
# 10613    9/8/2023 9:55      Kitten/Puppy
# 10614   9/8/2024 10:07  Stray without ID
# 10618   9/9/2023 13:47  Stray without ID
# 10619   9/9/2023 11:31      Kitten/Puppy
# 10627    9/9/2024 9:35     Stray with ID
#
#                                   Location Found Jurisdiction In  ...  ...20  \
# 1                      Carpenter  and  Ellsworth      Pittsfield  ...    NaN
# 5                   Around Michigan  and  Ecorse       Ypsilanti  ...    NaN
# 6                               Martz and Bunton       Ypsilanti  ...  193.0
# 10                           Prospect and Holmes       Ypsilanti  ...    NaN
# 12     Harris and Forest and Michigan and Holmes       Ypsilanti  ...    NaN
# ...                                          ...             ...  ...    ...
# 10613                   Austin st and Noggles Rd      Manchester  ...    NaN
# 10614                          Clark and Leforge        Superior  ...    NaN
# 10618                         Clark and Prospect        Superior  ...    NaN
# 10619                        Bemis and Whittaker       Ypsilanti  ...    NaN
# 10627                           Ridge and Geddes        Superior  ...    NaN
#
#            ...21 ...22    ...23  \
# 1      Ypsilanti    MI  48197.0
# 5      Ypsilanti    MI  48198.0
# 6      Ypsilanti    MI  48197.0
# 10     Ypsilanti    MI  48198.0
# 12     Ypsilanti    MI  48198.0
# ...          ...   ...      ...
# 10613        NaN   NaN      NaN
# 10614        NaN   NaN      NaN
# 10618        NaN   NaN      NaN
# 10619        NaN   NaN      NaN
# 10627        NaN   NaN      NaN
#
#                                             LocationPlus  \
# 1      Carpenter / Ellsworth WC-Pittsfield Twp , Mich...
# 5      Around Michigan / Ecorse WC-Ypsilanti Twp , Mi...
# 6           Martz and Bunton WC-Ypsilanti Twp , Michigan
# 10       Prospect and Holmes WC-Ypsilanti Twp , Michigan
# 12     Harris/Forest/Michigan/Holmes WC-Ypsilanti Twp...
# ...                                                  ...
# 10613  Austin st and Noggles Rd WC-Manchester Twp , M...
# 10614       Clark and Leforge WC-Superior Twp , Michigan
# 10618      Clark and Prospect WC-Superior Twp , Michigan
# 10619    Bemis and Whittaker WC-Ypsilanti Twp , Michigan
# 10627        Ridge and Geddes WC-Superior Twp , Michigan
#
#                                         address_google  \
# 1      E Ellsworth Rd, Pittsfield Charter Twp, MI, USA
# 5            Ecorse Dr, Ypsilanti Charter Twp, MI, USA
# 6                       Ypsilanti Charter Twp, MI, USA
# 10                      Ypsilanti Charter Twp, MI, USA
# 12                      Ypsilanti Charter Twp, MI, USA
# ...                                                ...
# 10613                     Manchester Township, MI, USA
# 10614        Leforge Rd, Superior Charter Twp, MI, USA
# 10618                    Superior Charter Twp, MI, USA
# 10619                   Ypsilanti Charter Twp, MI, USA
# 10627         Geddes Rd, Superior Charter Twp, MI, USA
#
#                            pnt        lon        lat  address_no_zipcode
# 1       -83.6995447, 42.230374 -83.699545  42.230374                True
# 5      -83.5463831, 42.2457404 -83.546383  42.245740                True
# 6      -83.6194916, 42.2101369 -83.619492  42.210137                True
# 10     -83.6194916, 42.2101369 -83.619492  42.210137                True
# 12     -83.6194916, 42.2101369 -83.619492  42.210137                True
# ...                        ...        ...        ...                 ...
# 10613  -84.0801613, 42.1035271 -84.080161  42.103527                True
# 10614  -83.6230319, 42.2738459 -83.623032  42.273846                True
# 10618  -83.6044771, 42.3046849 -83.604477  42.304685                True
# 10619  -83.6194916, 42.2101369 -83.619492  42.210137                True
# 10627  -83.6030416, 42.2755979 -83.603042  42.275598                True
#
# [2825 rows x 29 columns]

# %% [markdown]
# #### Around 1663 rows that are not mentioning a more granular location

# %%
hshv_no_zipcode = hshv_no_zipcode.copy()
hshv_no_zipcode.loc[:,'no_full_address'] = ~hshv_no_zipcode.loc[:, 'address_google'].str.contains(r'Ave|Rd|Dr|Trail|St|Pkwy|&|Park|Lake', regex=True, na=False)
hshv_no_fulladd = hshv_no_zipcode[hshv_no_zipcode['no_full_address'] == True]
hshv_no_fulladd['address_google'].unique()
hshv_no_fulladd
# Out:
#         ...1     Animal # Species       Primary Breed Gender Altered  \
# 6          7  A0040598374     Cat  Domestic Shorthair      M     Yes
# 10        11  A0040613747     Cat  Domestic Shorthair      M     Yes
# 12        13  A0005951543     Cat  Domestic Shorthair      F     Yes
# 14        15  A0047526328     Dog      Siberian Husky      F     Yes
# 21        22  A0041596040     Dog   Terrier, Pit Bull      M     Yes
# ...      ...          ...     ...                 ...    ...     ...
# 10604  11316  A0054115026     Cat   Domestic Longhair      F     Yes
# 10605  11317  A0054115027     Cat  Domestic Shorthair      F     Yes
# 10613  11325  A0054114230     Cat  Domestic Shorthair      F     Yes
# 10618  11330  A0054122829     Dog   Poodle, Miniature      F     Yes
# 10619  11331  A0054121764     Cat  Domestic Shorthair      F      No
#
#             Intake Date    Intake Subtype  \
# 6       1/18/2019 15:44  Stray without ID
# 10       1/22/2019 8:49  Stray without ID
# 12      1/24/2019 12:09     Stray with ID
# 14      1/26/2019 16:19     Stray with ID
# 21     10/11/2019 11:05     Stray with ID
# ...                 ...               ...
# 10604    9/8/2023 11:19      Kitten/Puppy
# 10605    9/8/2023 11:19      Kitten/Puppy
# 10613     9/8/2023 9:55      Kitten/Puppy
# 10618    9/9/2023 13:47  Stray without ID
# 10619    9/9/2023 11:31      Kitten/Puppy
#
#                                   Location Found Jurisdiction In  ...  \
# 6                               Martz and Bunton       Ypsilanti  ...
# 10                           Prospect and Holmes       Ypsilanti  ...
# 12     Harris and Forest and Michigan and Holmes       Ypsilanti  ...
# 14                           Geddes  and  Harris        Superior  ...
# 21                    Michigan Ave and Mansfield       Ypsilanti  ...
# ...                                          ...             ...  ...
# 10604         M-52 btwn Pleasant Lake and Pekins          Sharon  ...
# 10605         M-52 btwn Pleasant Lake and Pekins          Sharon  ...
# 10613                   Austin st and Noggles Rd      Manchester  ...
# 10618                         Clark and Prospect        Superior  ...
# 10619                        Bemis and Whittaker       Ypsilanti  ...
#
#            ...21 ...22    ...23  \
# 6      Ypsilanti    MI  48197.0
# 10     Ypsilanti    MI  48198.0
# 12     Ypsilanti    MI  48198.0
# 14     Ypsilanti    MI  48198.0
# 21     Ypsilanti    MI  48197.0
# ...          ...   ...      ...
# 10604        NaN   NaN      NaN
# 10605        NaN   NaN      NaN
# 10613        NaN   NaN      NaN
# 10618        NaN   NaN      NaN
# 10619        NaN   NaN      NaN
#
#                                             LocationPlus  \
# 6           Martz and Bunton WC-Ypsilanti Twp , Michigan
# 10       Prospect and Holmes WC-Ypsilanti Twp , Michigan
# 12     Harris/Forest/Michigan/Holmes WC-Ypsilanti Twp...
# 14            Geddes / Harris WC-Superior Twp , Michigan
# 21     Michigan Ave and Mansfield WC-Ypsilanti City ,...
# ...                                                  ...
# 10604  M-52 btwn Pleasant Lake and Pekins WC-Sharon T...
# 10605  M-52 btwn Pleasant Lake and Pekins WC-Sharon T...
# 10613  Austin st and Noggles Rd WC-Manchester Twp , M...
# 10618      Clark and Prospect WC-Superior Twp , Michigan
# 10619    Bemis and Whittaker WC-Ypsilanti Twp , Michigan
#
#                        address_google                      pnt        lon  \
# 6      Ypsilanti Charter Twp, MI, USA  -83.6194916, 42.2101369 -83.619492
# 10     Ypsilanti Charter Twp, MI, USA  -83.6194916, 42.2101369 -83.619492
# 12     Ypsilanti Charter Twp, MI, USA  -83.6194916, 42.2101369 -83.619492
# 14      Superior Charter Twp, MI, USA  -83.6044771, 42.3046849 -83.604477
# 21                 Ypsilanti, MI, USA  -83.6129939, 42.2411499 -83.612994
# ...                               ...                      ...        ...
# 10604        Sharon Township, MI, USA  -84.0801613, 42.2216618 -84.080161
# 10605        Sharon Township, MI, USA  -84.0801613, 42.2216618 -84.080161
# 10613    Manchester Township, MI, USA  -84.0801613, 42.1035271 -84.080161
# 10618   Superior Charter Twp, MI, USA  -83.6044771, 42.3046849 -83.604477
# 10619  Ypsilanti Charter Twp, MI, USA  -83.6194916, 42.2101369 -83.619492
#
#              lat address_no_zipcode  no_full_address
# 6      42.210137               True             True
# 10     42.210137               True             True
# 12     42.210137               True             True
# 14     42.304685               True             True
# 21     42.241150               True             True
# ...          ...                ...              ...
# 10604  42.221662               True             True
# 10605  42.221662               True             True
# 10613  42.103527               True             True
# 10618  42.304685               True             True
# 10619  42.210137               True             True
#
# [1663 rows x 30 columns]

# %% [markdown]
# #### Drop the above columns from our analyses since location isn't specific (8965 rows left)

# %%
folium_df = folium_df[~folium_df.index.isin(hshv_no_fulladd.index)]
folium_df
# Out:
#         ...1     Animal # Species          Primary Breed Gender Altered  \
# 0          1  A0040552205     Cat      Domestic Longhair      M     Yes
# 1          2  A0040554409     Dog    Retriever, Labrador      F     Yes
# 2          3  A0033047934     Dog                Terrier      M     Yes
# 3          4  A0035187693     Dog  Terrier, Jack Russell      M     Yes
# 4          5  A0040580759     Cat     Domestic Shorthair      M     Yes
# ...      ...          ...     ...                    ...    ...     ...
# 10623  11335  A0056846624     Cat     Domestic Shorthair      F     Yes
# 10624  11337  A0056849779     Cat   Domestic Medium Hair      M     Yes
# 10625  11338  A0056851074     Cat     Domestic Shorthair      F     Yes
# 10626  11339  A0056851629     Cat     Domestic Shorthair      M     Yes
# 10627  11340  A0049406005     Cat     Domestic Shorthair      F     Yes
#
#            Intake Date    Intake Subtype                  Location Found  \
# 0      1/12/2019 11:23     Stray with ID  Huron River Dr and Tuttle Hill
# 1      1/12/2019 15:06     Stray with ID       Carpenter  and  Ellsworth
# 2      1/13/2019 12:11     Stray with ID         Waters rd and Wagner Rd
# 3       1/14/2019 9:03     Stray with ID               Adams and Harriet
# 4      1/16/2019 14:51  Stray without ID             Oakwood and Sherman
# ...                ...               ...                             ...
# 10623   9/9/2024 10:02     Stray with ID   Carpenter rd and Washtenaw Rd
# 10624   9/9/2024 14:16  Stray without ID   Wilcox and Edwards N Hines Dr
# 10625   9/9/2024 16:00      Kitten/Puppy              Joy Rd and Main St
# 10626   9/9/2024 16:52     Stray with ID     Carpenter and Washtenaw Ave
# 10627    9/9/2024 9:35     Stray with ID                Ridge and Geddes
#
#       Jurisdiction In  ... ...20      ...21 ...22    ...23  \
# 0           Ypsilanti  ...   NaN  Ypsilanti    MI  48197.0
# 1          Pittsfield  ...   NaN  Ypsilanti    MI  48197.0
# 2                Scio  ...   NaN  Ann Arbor    MI  48103.0
# 3           Ypsilanti  ...   NaN  Ypsilanti    MI  48197.0
# 4           Ypsilanti  ...   NaN  Ypsilanti    MI  48198.0
# ...               ...  ...   ...        ...   ...      ...
# 10623      Pittsfield  ...   NaN        NaN   NaN      NaN
# 10624        Plymouth  ...   NaN        NaN   NaN      NaN
# 10625        Plymouth  ...   NaN        NaN   NaN      NaN
# 10626      Pittsfield  ...   NaN        NaN   NaN      NaN
# 10627        Superior  ...   NaN        NaN   NaN      NaN
#
#                                             LocationPlus  \
# 0      Huron River Dr and Tuttle Hill WC-Ypsilanti Tw...
# 1      Carpenter / Ellsworth WC-Pittsfield Twp , Mich...
# 2         Waters rd and Wagner Rd WC-Scio Twp , Michigan
# 3         Adams and Harriet WC-Ypsilanti City , Michigan
# 4           Oakwood/Sherman WC-Ypsilanti City , Michigan
# ...                                                  ...
# 10623  Carpenter rd and Washtenaw Rd WC-Pittsfield Tw...
# 10624  Wilcox and Edwards N Hines Dr Plymouth City , ...
# 10625         Joy Rd and Main St Plymouth Twp , Michigan
# 10626  Carpenter and Washtenaw Ave WC-Pittsfield Twp ...
# 10627        Ridge and Geddes WC-Superior Twp , Michigan
#
#                                           address_google  \
# 0      S Huron River Dr & Tuttle Hill Rd, Ypsilanti C...
# 1        E Ellsworth Rd, Pittsfield Charter Twp, MI, USA
# 2      W Waters Rd & S Wagner Rd, Lodi Township, MI 4...
# 3                   Harriet St, Ypsilanti, MI 48197, USA
# 4      Sherman St & Oakwood St, Ypsilanti, MI 48197, USA
# ...                                                  ...
# 10623  Washtenaw Ave & Carpenter Rd, Pittsfield Chart...
# 10624  Edward N Hines Dr, Plymouth Charter Twp, MI 48...
# 10625  S Main St & Joy Rd, Plymouth Charter Twp, MI 4...
# 10626  Washtenaw Ave & Carpenter Rd, Pittsfield Chart...
# 10627           Geddes Rd, Superior Charter Twp, MI, USA
#
#                            pnt        lon        lat  address_no_zipcode
# 0       -83.5819195, 42.210799 -83.581919  42.210799               False
# 1       -83.6995447, 42.230374 -83.699545  42.230374                True
# 2       -83.7984686, 42.242459 -83.798469  42.242459               False
# 3      -83.6201156, 42.2335459 -83.620116  42.233546               False
# 4       -83.6289739, 42.243699 -83.628974  42.243699               False
# ...                        ...        ...        ...                 ...
# 10623  -83.6807369, 42.2540335 -83.680737  42.254033               False
# 10624   -83.4683398, 42.394534 -83.468340  42.394534               False
# 10625  -83.4691092, 42.3515033 -83.469109  42.351503               False
# 10626  -83.6807369, 42.2540335 -83.680737  42.254033               False
# 10627  -83.6030416, 42.2755979 -83.603042  42.275598                True
#
# [8965 rows x 29 columns]

# %% [markdown]
# #### Remove duplicates based on 'Intake Date', 'Species', 'Primary Breed', 'Location Found', 'Returned to Address' (3910 duplicates)

# %%
dup_factors = ['Intake Date', 'Species', 'Primary Breed', 'Location Found', 'Returned to Address']
folium_df['Duplicates'] = folium_df.duplicated(subset=dup_factors, keep=False).astype(int)
duplicates = folium_df[folium_df['Duplicates'] == 1].copy()
duplicates
# Out:
#         ...1     Animal # Species        Primary Breed Gender Altered  \
# 190      195  A0042782397     Dog    Terrier, Pit Bull      M     Yes
# 191      196  A0042782398     Dog    Terrier, Pit Bull      F     Yes
# 251      257  A0046185537     Cat   Domestic Shorthair      M      No
# 252      258  A0046185542     Cat   Domestic Shorthair      M      No
# 297      307  A0023963675     Dog  Retriever, Labrador      M     Yes
# ...      ...          ...     ...                  ...    ...     ...
# 10608  11320  A0054119203     Dog    Terrier, Pit Bull      M     Yes
# 10609  11321  A0054119206     Dog    Terrier, Pit Bull      F     Yes
# 10610  11322  A0054120050     Cat   Domestic Shorthair      M     Yes
# 10611  11323  A0054120055     Cat   Domestic Shorthair      M     Yes
# 10612  11324  A0054120056     Cat   Domestic Shorthair      M     Yes
#
#             Intake Date    Intake Subtype  \
# 190      9/20/2019 9:59  Stray without ID
# 191      9/20/2019 9:59  Stray without ID
# 251    11/30/2020 16:30  Stray without ID
# 252    11/30/2020 16:30  Stray without ID
# 297     3/19/2020 17:34     Stray with ID
# ...                 ...               ...
# 10608    9/8/2023 16:29  Stray without ID
# 10609    9/8/2023 16:29  Stray without ID
# 10610    9/8/2023 17:47      Kitten/Puppy
# 10611    9/8/2023 17:47      Kitten/Puppy
# 10612    9/8/2023 17:47      Kitten/Puppy
#
#                                  Location Found Jurisdiction In  ...  \
# 190                       Packard and Turnberry       Ann Arbor  ...
# 191                       Packard and Turnberry       Ann Arbor  ...
# 251                  Leforge and Huron River Dr       Ypsilanti  ...
# 252                  Leforge and Huron River Dr       Ypsilanti  ...
# 297            Pontiac Trail and N. Territorial           Salem  ...
# ...                                         ...             ...  ...
# 10608               Fuller rd and Huron Parkway       Ann Arbor  ...
# 10609               Fuller rd and Huron Parkway       Ann Arbor  ...
# 10610  EMU Campus: Oakwood St and Washtenaw Ave       Ypsilanti  ...
# 10611  EMU Campus: Oakwood St and Washtenaw Ave       Ypsilanti  ...
# 10612  EMU Campus: Oakwood St and Washtenaw Ave       Ypsilanti  ...
#
#            ...21 ...22    ...23  \
# 190    Ann Arbor    MI  48108.0
# 191    Ann Arbor    MI  48108.0
# 251    Ypsilanti    MI  48197.0
# 252    Ypsilanti    MI  48197.0
# 297    Ann Arbor    MI  48105.0
# ...          ...   ...      ...
# 10608        NaN   NaN      NaN
# 10609        NaN   NaN      NaN
# 10610        NaN   NaN      NaN
# 10611        NaN   NaN      NaN
# 10612        NaN   NaN      NaN
#
#                                             LocationPlus  \
# 190    Packard and Turnberry WC-Ann Arbor City , Mich...
# 191    Packard and Turnberry WC-Ann Arbor City , Mich...
# 251    Leforge and Huron River Dr WC-Ypsilanti City ,...
# 252    Leforge and Huron River Dr WC-Ypsilanti City ,...
# 297    Pontiac Trail and N. Territorial WC-Salem Twp ...
# ...                                                  ...
# 10608  Fuller rd and Huron Parkway WC-Ann Arbor City ...
# 10609  Fuller rd and Huron Parkway WC-Ann Arbor City ...
# 10610  EMU Campus: Oakwood St and Washtenaw Ave WC-Yp...
# 10611  EMU Campus: Oakwood St and Washtenaw Ave WC-Yp...
# 10612  EMU Campus: Oakwood St and Washtenaw Ave WC-Yp...
#
#                                           address_google  \
# 190    Packard St & Turnberry Ln, Ann Arbor, MI 48108...
# 191    Packard St & Turnberry Ln, Ann Arbor, MI 48108...
# 251    Leforge Rd & N Huron River Dr, Ypsilanti, MI 4...
# 252    Leforge Rd & N Huron River Dr, Ypsilanti, MI 4...
# 297      E North Territorial Rd, Salem Township, MI, USA
# ...                                                  ...
# 10608   Fuller Rd & Huron Pkwy, Ann Arbor, MI 48105, USA
# 10609   Fuller Rd & Huron Pkwy, Ann Arbor, MI 48105, USA
# 10610           900 Oakwood St, Ypsilanti, MI 48197, USA
# 10611           900 Oakwood St, Ypsilanti, MI 48197, USA
# 10612           900 Oakwood St, Ypsilanti, MI 48197, USA
#
#                            pnt        lon        lat address_no_zipcode  \
# 190     -83.6875647, 42.245323 -83.687565  42.245323              False
# 191     -83.6875647, 42.245323 -83.687565  42.245323              False
# 251    -83.6223608, 42.2544429 -83.622361  42.254443              False
# 252    -83.6223608, 42.2544429 -83.622361  42.254443              False
# 297    -83.6619289, 42.3652126 -83.661929  42.365213               True
# ...                        ...        ...        ...                ...
# 10608  -83.6990446, 42.2776226 -83.699045  42.277623              False
# 10609  -83.6990446, 42.2776226 -83.699045  42.277623              False
# 10610   -83.624089, 42.2506803 -83.624089  42.250680              False
# 10611   -83.624089, 42.2506803 -83.624089  42.250680              False
# 10612   -83.624089, 42.2506803 -83.624089  42.250680              False
#
#        Duplicates
# 190             1
# 191             1
# 251             1
# 252             1
# 297             1
# ...           ...
# 10608           1
# 10609           1
# 10610           1
# 10611           1
# 10612           1
#
# [3674 rows x 30 columns]

# %%
folium_df = folium_df.drop('address_no_zipcode', axis=1)
folium_df.to_csv('C:/Users/khapr/OneDrive/Documents/MS BIOSTAT/HSHV/final_duplicateasindicator.csv', index=False)

# %% [markdown]
# #### We are left with 6424 datapoints in total that are not duplicates

# %%
df_noduplicates = folium_df.drop_duplicates(subset=dup_factors, keep='first').reset_index(drop=True).copy()
df_noduplicates
# Out:
#        ...1     Animal # Species          Primary Breed Gender Altered  \
# 0         1  A0040552205     Cat      Domestic Longhair      M     Yes
# 1         2  A0040554409     Dog    Retriever, Labrador      F     Yes
# 2         3  A0033047934     Dog                Terrier      M     Yes
# 3         4  A0035187693     Dog  Terrier, Jack Russell      M     Yes
# 4         5  A0040580759     Cat     Domestic Shorthair      M     Yes
# ...     ...          ...     ...                    ...    ...     ...
# 6419  11335  A0056846624     Cat     Domestic Shorthair      F     Yes
# 6420  11337  A0056849779     Cat   Domestic Medium Hair      M     Yes
# 6421  11338  A0056851074     Cat     Domestic Shorthair      F     Yes
# 6422  11339  A0056851629     Cat     Domestic Shorthair      M     Yes
# 6423  11340  A0049406005     Cat     Domestic Shorthair      F     Yes
#
#           Intake Date    Intake Subtype                  Location Found  \
# 0     1/12/2019 11:23     Stray with ID  Huron River Dr and Tuttle Hill
# 1     1/12/2019 15:06     Stray with ID       Carpenter  and  Ellsworth
# 2     1/13/2019 12:11     Stray with ID         Waters rd and Wagner Rd
# 3      1/14/2019 9:03     Stray with ID               Adams and Harriet
# 4     1/16/2019 14:51  Stray without ID             Oakwood and Sherman
# ...               ...               ...                             ...
# 6419   9/9/2024 10:02     Stray with ID   Carpenter rd and Washtenaw Rd
# 6420   9/9/2024 14:16  Stray without ID   Wilcox and Edwards N Hines Dr
# 6421   9/9/2024 16:00      Kitten/Puppy              Joy Rd and Main St
# 6422   9/9/2024 16:52     Stray with ID     Carpenter and Washtenaw Ave
# 6423    9/9/2024 9:35     Stray with ID                Ridge and Geddes
#
#      Jurisdiction In  ... ...20      ...21 ...22    ...23  \
# 0          Ypsilanti  ...   NaN  Ypsilanti    MI  48197.0
# 1         Pittsfield  ...   NaN  Ypsilanti    MI  48197.0
# 2               Scio  ...   NaN  Ann Arbor    MI  48103.0
# 3          Ypsilanti  ...   NaN  Ypsilanti    MI  48197.0
# 4          Ypsilanti  ...   NaN  Ypsilanti    MI  48198.0
# ...              ...  ...   ...        ...   ...      ...
# 6419      Pittsfield  ...   NaN        NaN   NaN      NaN
# 6420        Plymouth  ...   NaN        NaN   NaN      NaN
# 6421        Plymouth  ...   NaN        NaN   NaN      NaN
# 6422      Pittsfield  ...   NaN        NaN   NaN      NaN
# 6423        Superior  ...   NaN        NaN   NaN      NaN
#
#                                            LocationPlus  \
# 0     Huron River Dr and Tuttle Hill WC-Ypsilanti Tw...
# 1     Carpenter / Ellsworth WC-Pittsfield Twp , Mich...
# 2        Waters rd and Wagner Rd WC-Scio Twp , Michigan
# 3        Adams and Harriet WC-Ypsilanti City , Michigan
# 4          Oakwood/Sherman WC-Ypsilanti City , Michigan
# ...                                                 ...
# 6419  Carpenter rd and Washtenaw Rd WC-Pittsfield Tw...
# 6420  Wilcox and Edwards N Hines Dr Plymouth City , ...
# 6421         Joy Rd and Main St Plymouth Twp , Michigan
# 6422  Carpenter and Washtenaw Ave WC-Pittsfield Twp ...
# 6423        Ridge and Geddes WC-Superior Twp , Michigan
#
#                                          address_google  \
# 0     S Huron River Dr & Tuttle Hill Rd, Ypsilanti C...
# 1       E Ellsworth Rd, Pittsfield Charter Twp, MI, USA
# 2     W Waters Rd & S Wagner Rd, Lodi Township, MI 4...
# 3                  Harriet St, Ypsilanti, MI 48197, USA
# 4     Sherman St & Oakwood St, Ypsilanti, MI 48197, USA
# ...                                                 ...
# 6419  Washtenaw Ave & Carpenter Rd, Pittsfield Chart...
# 6420  Edward N Hines Dr, Plymouth Charter Twp, MI 48...
# 6421  S Main St & Joy Rd, Plymouth Charter Twp, MI 4...
# 6422  Washtenaw Ave & Carpenter Rd, Pittsfield Chart...
# 6423           Geddes Rd, Superior Charter Twp, MI, USA
#
#                           pnt        lon        lat  Duplicates
# 0      -83.5819195, 42.210799 -83.581919  42.210799           0
# 1      -83.6995447, 42.230374 -83.699545  42.230374           0
# 2      -83.7984686, 42.242459 -83.798469  42.242459           0
# 3     -83.6201156, 42.2335459 -83.620116  42.233546           0
# 4      -83.6289739, 42.243699 -83.628974  42.243699           0
# ...                       ...        ...        ...         ...
# 6419  -83.6807369, 42.2540335 -83.680737  42.254033           0
# 6420   -83.4683398, 42.394534 -83.468340  42.394534           0
# 6421  -83.4691092, 42.3515033 -83.469109  42.351503           0
# 6422  -83.6807369, 42.2540335 -83.680737  42.254033           0
# 6423  -83.6030416, 42.2755979 -83.603042  42.275598           0
#
# [6424 rows x 29 columns]

# %%
df_noduplicates.to_csv('C:/Users/khapr/OneDrive/Documents/MS BIOSTAT/HSHV/final_noduplicates.csv', index=False)

# %% [markdown]
# ## Folium with Modified Dataset

# %% [markdown]
# #### Heatmap of where Lost Pets were found

# %%
from folium.plugins import HeatMap
map_center = [df_noduplicates['lat'].mean(), df_noduplicates['lon'].mean()]
m = folium.Map(location=map_center, zoom_start=10)
heat_data = df_noduplicates[['lat', 'lon']].values.tolist()
HeatMap(heat_data, radius=15).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_64b71cde4e95be5e9ed54771d8a82afd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_64b71cde4e95be5e9ed54771d8a82afd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_64b71cde4e95be5e9ed54771d8a82afd = L.map(
#                 &quot;map_64b71cde4e95be5e9ed54771d8a82afd&quot;,
#                 {
#                     center: [42.26786197887609, -83.67608022115505],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_08c6fa5d7131078f0ae9f89f9de7f1d8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_08c6fa5d7131078f0ae9f89f9de7f1d8.addTo(map_64b71cde4e95be5e9ed54771d8a82afd);
#
#
#             var heat_map_1961b3e2dfaf78c29e841c42df7b820e = L.heatLayer(
#                 [[42.210799, -83.5819195], [42.230374, -83.6995447], [42.242459, -83.7984686], [42.2335459, -83.6201156], [42.243699, -83.6289739], [42.2457404, -83.5463831], [42.289214, -83.76631], [42.2412324, -83.5802177], [42.2412324, -83.5802177], [42.253766, -83.7667756], [42.213804, -83.544421], [42.235002, -83.645903], [42.2979795, -83.7213902], [42.2412324, -83.5802177], [42.2709114, -83.7406201], [42.2036842, -83.5431817], [42.3035028, -83.653651], [42.2560381, -83.6295775], [42.1568846, -83.6972154], [42.2303704, -83.6996729], [42.3721466, -83.6629493], [42.1992248, -83.5651156], [42.1666801, -83.7813167], [42.2306712, -83.638874], [42.2594101, -83.6612184], [42.0829839, -83.6766434], [42.210799, -83.5819195], [42.1575648, -83.5814202], [42.2449466, -83.6609532], [42.1679374, -83.4419256], [42.3158206, -83.780132], [42.230374, -83.6995447], [42.3586272, -83.5086986], [42.2883847, -83.8385504], [42.3172392, -83.6483248], [42.2450694, -83.7001271], [42.2450694, -83.7001271], [42.2499921, -83.5831599], [42.3134165, -84.0203556], [42.2450694, -83.7001271], [42.2450694, -83.7001271], [42.2455332, -83.6804906], [42.2753142, -83.7712151], [42.2534729, -83.6029146], [42.3669869, -83.6072652], [42.3586272, -83.5086986], [42.2412324, -83.5802177], [42.2380381, -83.6245898], [42.21361, -83.557431], [42.1560762, -83.6530316], [42.2302096, -83.6606109], [42.2196857, -83.6603068], [42.2944721, -83.7802448], [42.1716979, -83.6792563], [42.2962151, -83.7309258], [42.288742, -83.6529707], [42.2027786, -83.581733], [42.2888697, -83.7655861], [42.202561, -83.609847], [42.2561271, -83.5441086], [42.2412324, -83.5802177], [42.1357921, -83.6778336], [42.1357921, -83.6778336], [42.2031269, -83.9340528], [42.241168, -83.582753], [42.258063, -83.562182], [42.3817593, -83.8234029], [42.306139, -83.654887], [42.1703662, -83.7699827], [42.2607809, -83.7298785], [42.3255802, -83.8394495], [42.288079, -83.838546], [42.259215, -83.607771], [42.2562631, -83.7111541], [42.2440692, -83.719857], [42.3602997, -83.7711439], [42.1872525, -83.6205697], [42.2506803, -83.624089], [42.3817593, -83.8234029], [41.9857288, -83.3688523], [42.2458513, -83.6263711], [42.1810072, -83.5739128], [42.2580513, -83.6625715], [42.230374, -83.6995447], [42.230374, -83.6995447], [42.2755979, -83.6030416], [42.2833599, -83.7012017], [42.2947202, -83.7807865], [42.30416, -83.707201], [42.2833599, -83.7012017], [42.247677, -83.719853], [42.2459938, -83.6085497], [42.062968, -83.650484], [42.3170217, -83.7067277], [42.306117, -83.709707], [42.4325296, -83.1028274], [42.3025991, -83.70431], [42.2501431, -83.6610765], [42.2560381, -83.6295775], [42.3255802, -83.8394495], [42.2634589, -83.5805566], [42.181727, -83.542378], [42.2779521, -83.7585343], [42.1666801, -83.7813167], [42.2760992, -83.5834128], [42.2560381, -83.6295775], [42.3161944, -83.7341529], [42.2335459, -83.6201156], [42.2297949, -83.7195774], [42.1417412, -83.7142811], [42.3290415, -83.6169352], [42.1460527, -84.0468632], [42.2939293, -83.8779342], [42.202931, -83.582843], [42.2814211, -83.7485636], [42.300452, -83.7358149], [42.2809974, -83.7818094], [42.2461577, -83.5978184], [42.202561, -83.609847], [42.2589, -83.677791], [42.2705525, -83.7298399], [42.2209852, -83.6973183], [42.3343626, -83.6061534], [42.2994292, -83.7771025], [42.2741719, -83.7767184], [42.2562965, -83.7764965], [42.4114695, -83.9136616], [42.3182336, -83.6833799], [42.3171722, -83.7133185], [42.2434879, -83.5759435], [42.288159, -83.833627], [42.2833599, -83.7012017], [42.2412324, -83.5802177], [42.2464382, -83.613813], [42.245124, -83.700858], [42.2387124, -83.7718536], [42.210799, -83.5819195], [42.3748845, -83.4804482], [42.1682472, -84.091419], [42.289214, -83.76631], [42.2776226, -83.6990446], [42.2738459, -83.6230319], [42.4214766, -83.7463049], [42.3198536, -84.0122243], [42.26843, -83.758633], [42.4027208, -83.7160217], [42.4027208, -83.7160

# %% [markdown]
# #### Heatmap of where Lost Pets who were not Returned were found

# %%
df_nodup_notreturned = df_noduplicates[df_noduplicates['Returned to Address'].isna()].copy()
df_nodup_notreturned
# Out:
#        ...1     Animal # Species                      Primary Breed Gender  \
# 20       27  A0018665727     Dog                Retriever, Labrador      F
# 67       82  A0018665727     Dog                Retriever, Labrador      F
# 80       96  A0041109176     Dog                 Miniature Pinscher      F
# 119     149  A0042171159     Cat                            Persian      M
# 125     157  A0042297098     Dog  Dachshund, Standard Smooth Haired      M
# ...     ...          ...     ...                                ...    ...
# 6419  11335  A0056846624     Cat                 Domestic Shorthair      F
# 6420  11337  A0056849779     Cat               Domestic Medium Hair      M
# 6421  11338  A0056851074     Cat                 Domestic Shorthair      F
# 6422  11339  A0056851629     Cat                 Domestic Shorthair      M
# 6423  11340  A0049406005     Cat                 Domestic Shorthair      F
#
#      Altered       Intake Date    Intake Subtype  \
# 20       Yes  10/13/2019 16:33     Stray with ID
# 67       Yes   12/9/2019 17:39     Stray with ID
# 80       Yes   3/19/2019 16:39     Stray with ID
# 119      Yes   7/12/2019 11:27  Stray without ID
# 125      Yes   7/24/2019 12:32  Stray without ID
# ...      ...               ...               ...
# 6419     Yes    9/9/2024 10:02     Stray with ID
# 6420     Yes    9/9/2024 14:16  Stray without ID
# 6421     Yes    9/9/2024 16:00      Kitten/Puppy
# 6422     Yes    9/9/2024 16:52     Stray with ID
# 6423     Yes     9/9/2024 9:35     Stray with ID
#
#                      Location Found Jurisdiction In  ... ...20 ...21 ...22  \
# 20                     Dixboro Road       Ann Arbor  ...   NaN   NaN   NaN
# 67                  Adoptions lobby            HSHV  ...   NaN   NaN   NaN
# 80              Cross and Washtenaw       Ypsilanti  ...   NaN   NaN   NaN
# 119               Clark and Hogback      Pittsfield  ...   NaN   NaN   NaN
# 125    West Liberty and Scio Church       Ann Arbor  ...   NaN   NaN   NaN
# ...                             ...             ...  ...   ...   ...   ...
# 6419  Carpenter rd and Washtenaw Rd      Pittsfield  ...   NaN   NaN   NaN
# 6420  Wilcox and Edwards N Hines Dr        Plymouth  ...   NaN   NaN   NaN
# 6421             Joy Rd and Main St        Plymouth  ...   NaN   NaN   NaN
# 6422    Carpenter and Washtenaw Ave      Pittsfield  ...   NaN   NaN   NaN
# 6423               Ridge and Geddes        Superior  ...   NaN   NaN   NaN
#
#      ...23                                       LocationPlus  \
# 20     NaN          Dixboro Road WC-Ann Arbor City , Michigan
# 67     NaN                 Adoptions lobby WC-HSHV , Michigan
# 80     NaN    Cross and Washtenaw WC-Ypsilanti Twp , Michigan
# 119    NaN         Clark/Hogback WC-Pittsfield Twp , Michigan
# 125    NaN  West Liberty/Scio Church WC-Ann Arbor City , M...
# ...    ...                                                ...
# 6419   NaN  Carpenter rd and Washtenaw Rd WC-Pittsfield Tw...
# 6420   NaN  Wilcox and Edwards N Hines Dr Plymouth City , ...
# 6421   NaN         Joy Rd and Main St Plymouth Twp , Michigan
# 6422   NaN  Carpenter and Washtenaw Ave WC-Pittsfield Twp ...
# 6423   NaN        Ridge and Geddes WC-Superior Twp , Michigan
#
#                                          address_google  \
# 20                       Dixboro Rd, Ann Arbor, MI, USA
# 67             3100 Cherry Hill Rd, Ann Arbor, MI 48105
# 80    Washtenaw Ave & W Cross St, Ypsilanti, MI 4819...
# 119   Clark + Hogback, Pittsfield Charter Twp, MI 48...
# 125                  Scio Church Rd, Ann Arbor, MI, USA
# ...                                                 ...
# 6419  Washtenaw Ave & Carpenter Rd, Pittsfield Chart...
# 6420  Edward N Hines Dr, Plymouth Charter Twp, MI 48...
# 6421  S Main St & Joy Rd, Plymouth Charter Twp, MI 4...
# 6422  Washtenaw Ave & Carpenter Rd, Pittsfield Chart...
# 6423           Geddes Rd, Superior Charter Twp, MI, USA
#
#                           pnt        lon        lat  Duplicates
# 20    -83.6629493, 42.3721466 -83.662949  42.372147           0
# 67      -83.654887, 42.306139 -83.654887  42.306139           0
# 80    -83.6263711, 42.2458513 -83.626371  42.245851           0
# 119       -83.677791, 42.2589 -83.677791  42.258900           0
# 125   -83.7764965, 42.2562965 -83.776496  42.256296           0
# ...                       ...        ...        ...         ...
# 6419  -83.6807369, 42.2540335 -83.680737  42.254033           0
# 6420   -83.4683398, 42.394534 -83.468340  42.394534           0
# 6421  -83.4691092, 42.3515033 -83.469109  42.351503           0
# 6422  -83.6807369, 42.2540335 -83.680737  42.254033           0
# 6423  -83.6030416, 42.2755979 -83.603042  42.275598           0
#
# [5380 rows x 29 columns]

# %%
map_center = [df_nodup_notreturned['lat'].mean(), df_nodup_notreturned['lon'].mean()]
m = folium.Map(location=map_center, zoom_start=10)
heat_data = df_nodup_notreturned[['lat', 'lon']].values.tolist()
HeatMap(heat_data, radius=15).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7e9756275b4d77ba8593bb4f36ec2767 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7e9756275b4d77ba8593bb4f36ec2767&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7e9756275b4d77ba8593bb4f36ec2767 = L.map(
#                 &quot;map_7e9756275b4d77ba8593bb4f36ec2767&quot;,
#                 {
#                     center: [42.26770947065056, -83.67339839473978],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_db853c6b193fd4dd9e271d7dff3135ed = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_db853c6b193fd4dd9e271d7dff3135ed.addTo(map_7e9756275b4d77ba8593bb4f36ec2767);
#
#
#             var heat_map_15b32610121a189d0b13dbbb9e946516 = L.heatLayer(
#                 [[42.3721466, -83.6629493], [42.306139, -83.654887], [42.2458513, -83.6263711], [42.2589, -83.677791], [42.2562965, -83.7764965], [42.3343626, -83.6061534], [42.260762, -83.728343], [42.1564548, -83.7991679], [42.2623841, -83.5463949], [42.3118378, -83.6613099], [42.3118378, -83.6613099], [42.2246858, -83.6177585], [42.2246858, -83.6177585], [42.2596407, -83.651896], [42.3118378, -83.6613099], [42.3046765, -83.6044828], [42.2349611, -83.5826572], [42.3118378, -83.6613099], [42.2727543, -83.783283], [42.2852306, -83.7994843], [42.2411494, -83.6021516], [42.4121964, -83.589513], [42.2458513, -83.6263711], [42.2362154, -83.7593702], [42.23079, -83.699605], [42.3343626, -83.6061534], [42.2458132, -83.6135383], [42.3666107, -83.4453125], [42.2726541, -83.6982047], [42.291163, -83.564449], [42.2514522, -83.5685722], [42.162278, -83.7926684], [42.2878178, -83.7033928], [42.2349653, -83.6030614], [42.1806943, -83.950959], [42.2852306, -83.7994843], [42.3851837, -83.4613885], [42.2501431, -83.6610765], [42.273452, -84.1132072], [42.2028303, -83.5623908], [42.270175, -83.5832461], [42.2540335, -83.6807369], [42.300397, -83.1186723], [42.2438714, -83.7115472], [42.3121733, -83.6564611], [42.2374482, -83.6145164], [42.281863, -83.7622482], [42.306117, -83.709707], [42.246554, -83.680613], [42.2530933, -83.5805464], [42.2458132, -83.6135383], [42.3043169, -83.6193413], [42.3748845, -83.4804482], [42.413312, -83.8345601], [42.4311718, -83.6648098], [42.1521747, -83.3053896], [42.217352, -83.568207], [42.2581993, -83.6950515], [42.246554, -83.680613], [42.2574535, -83.6997438], [42.211215, -83.5971535], [42.3121805, -83.6560013], [42.3588784, -83.5266292], [42.3759507, -83.5289886], [42.213804, -83.544421], [42.2544429, -83.6223608], [42.261467, -83.594069], [42.2334976, -83.6333096], [42.3483853, -83.871941], [42.2729868, -83.5727624], [42.2019399, -83.6099856], [42.306139, -83.654887], [42.3172392, -83.6483248], [42.2755203, -83.6030404], [42.2147821, -83.5438596], [42.1783721, -84.093836], [42.2560381, -83.6295775], [42.4113228, -83.4692896], [42.085585, -83.5394067], [42.3793906, -83.7585366], [42.284936, -83.780574], [42.358435, -83.4596643], [42.130293, -83.5407145], [42.245619, -83.681552], [42.4317354, -83.6492757], [42.279463, -83.7447212], [42.439479, -83.7438303], [42.1409264, -83.752747], [42.4307017, -83.608006], [42.245919, -83.61282], [42.2696794, -83.8382128], [42.4135702, -83.8174865], [42.245921, -83.609886], [42.1994302, -83.9339138], [42.2583039, -83.5539111], [42.2411494, -83.6021516], [42.4012628, -83.6457001], [42.2755979, -83.6030416], [42.2561271, -83.5441086], [42.3714253, -83.4702132], [42.2875188, -83.8648646], [42.2374302, -83.6174547], [42.252567, -83.680583], [42.1900473, -83.483373], [42.2853851, -83.7804791], [42.2853851, -83.7804791], [42.233322, -83.5826005], [42.2063945, -83.9494555], [42.1667072, -83.7816075], [42.3540944, -83.5279846], [42.3448219, -83.7042837], [42.1148134, -83.5402028], [42.2459938, -83.6085497], [42.1932604, -83.5816188], [42.1930867, -83.6109524], [42.2534729, -83.6029146], [42.410668, -83.4323767], [42.2155224, -83.5519016], [42.2696794, -83.8382128], [42.4030585, -83.7226475], [42.2392782, -83.6221999], [42.1897493, -83.7282508], [42.2410878, -83.6130994], [42.2991666, -83.8388174], [42.2991666, -83.8388174], [42.0778735, -83.6859265], [42.2805951, -83.7326764], [42.2805951, -83.7326764], [42.3666107, -83.4453125], [42.3787114, -84.0472073], [42.1408341, -83.7573984], [42.4174646, -83.7125732], [42.2497341, -83.5636115], [42.277758, -83.759622], [42.2307427, -83.6800721], [42.3120398, -83.6563436], [42.2337172, -83.6329017], [42.2537657, -83.5805603], [42.3666107, -83.4453125], [42.3192294, -83.6049183], [42.3192294, -83.6049183], [42.2546718, -83.8378756], [42.1503177, -84.037723], [42.2565875, -83.760679], [42.2755203, -83.6030404], [42.0851066, -83.6957287], [42.2569845,
